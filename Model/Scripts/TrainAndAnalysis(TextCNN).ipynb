# %% [markdown]
# # Train and Data Analysis
#
# - Use Jupyter Notebook for training
# - Train on GCP to use Cuda

# %%
from Settings import Settings
Settings.learning_rate = 1e-4
Settings.epoch_num = 50
Settings.print_count = 5  # print 5 count for 1 epoch
Settings.batch_size = 20
Settings.drop_out = 0.6

# %%
from DataLoader import torch_dataset_loader
from TextCNN import Model
from Train import main_train

import json
import matplotlib.pyplot as plt

# %%
# Dataloaders
train_loader = torch_dataset_loader(Settings.train_path, Settings.batch_size, True, Settings.kwargs)
validation_loader = torch_dataset_loader(Settings.valid_path, Settings.batch_size, False, Settings.kwargs)
test_loader = torch_dataset_loader(Settings.test_path, Settings.batch_size, False, Settings.kwargs)

# %% [markdown]
# ## Train Text CNN Model

# %%
txtModel = Model()
log = main_train(txtModel, train_loader, validation_loader, "train.json", "model.h5")
# Out:
# Epoch  1 | 227/1137 batches | 24.50ms/ batch | BCE: 0.2870 | Accuracy: 14.54% |
# Epoch  1 | 454/1137 batches | 21.20ms/ batch | BCE: 0.2746 | Accuracy: 17.73% |
# Epoch  1 | 681/1137 batches | 20.09ms/ batch | BCE: 0.2648 | Accuracy: 20.12% |
# Epoch  1 | 908/1137 batches | 19.55ms/ batch | BCE: 0.2558 | Accuracy: 22.60% |
# Epoch  1 | 1135/1137 batches | 19.23ms/ batch | BCE: 0.2479 | Accuracy: 24.98% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   1 | time: 21.89s | BCE: 0.2479 | Accuracy: 25.00% |
# End of validation epoch   1 | time:  0.87s | BCE: 0.1652 | Accuracy: 52.83% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  2 | 227/1137 batches | 18.02ms/ batch | BCE: 0.2054 | Accuracy: 36.50% |
# Epoch  2 | 454/1137 batches | 17.95ms/ batch | BCE: 0.1989 | Accuracy: 38.77% |
# Epoch  2 | 681/1137 batches | 17.93ms/ batch | BCE: 0.1951 | Accuracy: 40.26% |
# Epoch  2 | 908/1137 batches | 17.92ms/ batch | BCE: 0.1909 | Accuracy: 41.62% |
# Epoch  2 | 1135/1137 batches | 17.90ms/ batch | BCE: 0.1888 | Accuracy: 42.36% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   2 | time: 20.38s | BCE: 0.1888 | Accuracy: 42.37% |
# End of validation epoch   2 | time:  1.02s | BCE: 0.1374 | Accuracy: 60.84% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  3 | 227/1137 batches | 18.04ms/ batch | BCE: 0.1685 | Accuracy: 48.88% |
# Epoch  3 | 454/1137 batches | 17.95ms/ batch | BCE: 0.1670 | Accuracy: 49.77% |
# Epoch  3 | 681/1137 batches | 17.93ms/ batch | BCE: 0.1645 | Accuracy: 50.76% |
# Epoch  3 | 908/1137 batches | 17.92ms/ batch | BCE: 0.1631 | Accuracy: 51.11% |
# Epoch  3 | 1135/1137 batches | 17.93ms/ batch | BCE: 0.1617 | Accuracy: 51.51% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   3 | time: 20.41s | BCE: 0.1618 | Accuracy: 51.50% |
# End of validation epoch   3 | time:  0.95s | BCE: 0.1237 | Accuracy: 64.90% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  4 | 227/1137 batches | 18.10ms/ batch | BCE: 0.1492 | Accuracy: 55.88% |
# Epoch  4 | 454/1137 batches | 17.99ms/ batch | BCE: 0.1479 | Accuracy: 56.64% |
# Epoch  4 | 681/1137 batches | 17.96ms/ batch | BCE: 0.1475 | Accuracy: 56.89% |
# Epoch  4 | 908/1137 batches | 17.94ms/ batch | BCE: 0.1483 | Accuracy: 56.57% |
# Epoch  4 | 1135/1137 batches | 17.93ms/ batch | BCE: 0.1478 | Accuracy: 56.78% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   4 | time: 20.41s | BCE: 0.1477 | Accuracy: 56.79% |
# End of validation epoch   4 | time:  0.87s | BCE: 0.1158 | Accuracy: 67.69% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  5 | 227/1137 batches | 18.06ms/ batch | BCE: 0.1404 | Accuracy: 59.10% |
# Epoch  5 | 454/1137 batches | 18.03ms/ batch | BCE: 0.1381 | Accuracy: 59.66% |
# Epoch  5 | 681/1137 batches | 18.01ms/ batch | BCE: 0.1380 | Accuracy: 59.57% |
# Epoch  5 | 908/1137 batches | 18.01ms/ batch | BCE: 0.1377 | Accuracy: 59.60% |
# Epoch  5 | 1135/1137 batches | 18.00ms/ batch | BCE: 0.1373 | Accuracy: 59.77% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   5 | time: 20.49s | BCE: 0.1373 | Accuracy: 59.75% |
# End of validation epoch   5 | time:  0.86s | BCE: 0.1114 | Accuracy: 68.74% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  6 | 227/1137 batches | 18.10ms/ batch | BCE: 0.1309 | Accuracy: 61.74% |
# Epoch  6 | 454/1137 batches | 18.04ms/ batch | BCE: 0.1314 | Accuracy: 61.30% |
# Epoch  6 | 681/1137 batches | 18.03ms/ batch | BCE: 0.1304 | Accuracy: 61.86% |
# Epoch  6 | 908/1137 batches | 18.03ms/ batch | BCE: 0.1305 | Accuracy: 62.00% |
# Epoch  6 | 1135/1137 batches | 18.01ms/ batch | BCE: 0.1301 | Accuracy: 62.27% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   6 | time: 20.50s | BCE: 0.1301 | Accuracy: 62.26% |
# End of validation epoch   6 | time:  1.03s | BCE: 0.1079 | Accuracy: 70.45% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  7 | 227/1137 batches | 17.98ms/ batch | BCE: 0.1244 | Accuracy: 64.27% |
# Epoch  7 | 454/1137 batches | 17.91ms/ batch | BCE: 0.1249 | Accuracy: 63.91% |
# Epoch  7 | 681/1137 batches | 17.88ms/ batch | BCE: 0.1247 | Accuracy: 63.91% |
# Epoch  7 | 908/1137 batches | 17.87ms/ batch | BCE: 0.1247 | Accuracy: 64.00% |
# Epoch  7 | 1135/1137 batches | 17.87ms/ batch | BCE: 0.1247 | Accuracy: 64.04% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   7 | time: 20.34s | BCE: 0.1248 | Accuracy: 64.01% |
# End of validation epoch   7 | time:  0.90s | BCE: 0.1038 | Accuracy: 71.36% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  8 | 227/1137 batches | 18.20ms/ batch | BCE: 0.1214 | Accuracy: 64.85% |
# Epoch  8 | 454/1137 batches | 18.10ms/ batch | BCE: 0.1217 | Accuracy: 64.94% |
# Epoch  8 | 681/1137 batches | 18.06ms/ batch | BCE: 0.1213 | Accuracy: 65.23% |
# Epoch  8 | 908/1137 batches | 18.04ms/ batch | BCE: 0.1213 | Accuracy: 65.15% |
# Epoch  8 | 1135/1137 batches | 18.03ms/ batch | BCE: 0.1206 | Accuracy: 65.35% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   8 | time: 20.52s | BCE: 0.1207 | Accuracy: 65.33% |
# End of validation epoch   8 | time:  1.03s | BCE: 0.1032 | Accuracy: 71.54% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  9 | 227/1137 batches | 18.04ms/ batch | BCE: 0.1194 | Accuracy: 66.74% |
# Epoch  9 | 454/1137 batches | 17.96ms/ batch | BCE: 0.1178 | Accuracy: 66.65% |
# Epoch  9 | 681/1137 batches | 17.94ms/ batch | BCE: 0.1178 | Accuracy: 66.65% |
# Epoch  9 | 908/1137 batches | 17.92ms/ batch | BCE: 0.1185 | Accuracy: 66.32% |
# Epoch  9 | 1135/1137 batches | 17.92ms/ batch | BCE: 0.1183 | Accuracy: 66.28% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   9 | time: 20.40s | BCE: 0.1183 | Accuracy: 66.30% |
# End of validation epoch   9 | time:  1.00s | BCE: 0.1028 | Accuracy: 71.57% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 10 | 227/1137 batches | 18.17ms/ batch | BCE: 0.1120 | Accuracy: 68.24% |
# Epoch 10 | 454/1137 batches | 18.06ms/ batch | BCE: 0.1135 | Accuracy: 68.09% |
# Epoch 10 | 681/1137 batches | 17.99ms/ batch | BCE: 0.1135 | Accuracy: 67.94% |
# Epoch 10 | 908/1137 batches | 17.95ms/ batch | BCE: 0.1139 | Accuracy: 67.70% |
# Epoch 10 | 1135/1137 batches | 17.93ms/ batch | BCE: 0.1141 | Accuracy: 67.70% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  10 | time: 20.41s | BCE: 0.1141 | Accuracy: 67.70% |
# End of validation epoch  10 | time:  0.87s | BCE: 0.0992 | Accuracy: 72.76% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 11 | 227/1137 batches | 18.08ms/ batch | BCE: 0.1115 | Accuracy: 68.74% |
# Epoch 11 | 454/1137 batches | 17.98ms/ batch | BCE: 0.1113 | Accuracy: 68.08% |
# Epoch 11 | 681/1137 batches | 17.98ms/ batch | BCE: 0.1112 | Accuracy: 68.44% |
# Epoch 11 | 908/1137 batches | 17.99ms/ batch | BCE: 0.1114 | Accuracy: 68.56% |
# Epoch 11 | 1135/1137 batches | 17.98ms/ batch | BCE: 0.1115 | Accuracy: 68.38% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  11 | time: 20.47s | BCE: 0.1115 | Accuracy: 68.38% |
# End of validation epoch  11 | time:  0.84s | BCE: 0.0986 | Accuracy: 72.73% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 12 | 227/1137 batches | 18.03ms/ batch | BCE: 0.1073 | Accuracy: 69.36% |
# Epoch 12 | 454/1137 batches | 17.95ms/ batch | BCE: 0.1087 | Accuracy: 69.42% |
# Epoch 12 | 681/1137 batches | 17.93ms/ batch | BCE: 0.1088 | Accuracy: 69.22% |
# Epoch 12 | 908/1137 batches | 17.91ms/ batch | BCE: 0.1096 | Accuracy: 69.04% |
# Epoch 12 | 1135/1137 batches | 17.90ms/ batch | BCE: 0.1087 | Accuracy: 69.20% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  12 | time: 20.38s | BCE: 0.1087 | Accuracy: 69.17% |
# End of validation epoch  12 | time:  1.03s | BCE: 0.0978 | Accuracy: 73.04% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 13 | 227/1137 batches | 17.98ms/ batch | BCE: 0.1058 | Accuracy: 70.35% |
# Epoch 13 | 454/1137 batches | 17.89ms/ batch | BCE: 0.1067 | Accuracy: 69.93% |
# Epoch 13 | 681/1137 batches | 17.87ms/ batch | BCE: 0.1064 | Accuracy: 70.01% |
# Epoch 13 | 908/1137 batches | 17.87ms/ batch | BCE: 0.1056 | Accuracy: 70.26% |
# Epoch 13 | 1135/1137 batches | 17.87ms/ batch | BCE: 0.1060 | Accuracy: 70.07% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  13 | time: 20.34s | BCE: 0.1060 | Accuracy: 70.06% |
# End of validation epoch  13 | time:  1.02s | BCE: 0.0962 | Accuracy: 72.80% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 14 | 227/1137 batches | 17.98ms/ batch | BCE: 0.1029 | Accuracy: 71.76% |
# Epoch 14 | 454/1137 batches | 17.91ms/ batch | BCE: 0.1041 | Accuracy: 70.76% |
# Epoch 14 | 681/1137 batches | 17.89ms/ batch | BCE: 0.1023 | Accuracy: 71.16% |
# Epoch 14 | 908/1137 batches | 17.88ms/ batch | BCE: 0.1025 | Accuracy: 71.21% |
# Epoch 14 | 1135/1137 batches | 17.87ms/ batch | BCE: 0.1034 | Accuracy: 70.88% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  14 | time: 20.34s | BCE: 0.1035 | Accuracy: 70.87% |
# End of validation epoch  14 | time:  0.99s | BCE: 0.0951 | Accuracy: 73.46% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 15 | 227/1137 batches | 18.06ms/ batch | BCE: 0.1017 | Accuracy: 71.85% |
# Epoch 15 | 454/1137 batches | 17.96ms/ batch | BCE: 0.1018 | Accuracy: 71.59% |
# Epoch 15 | 681/1137 batches | 17.94ms/ batch | BCE: 0.1018 | Accuracy: 71.32% |
# Epoch 15 | 908/1137 batches | 17.92ms/ batch | BCE: 0.1024 | Accuracy: 70.99% |
# Epoch 15 | 1135/1137 batches | 17.90ms/ batch | BCE: 0.1030 | Accuracy: 70.97% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  15 | time: 20.38s | BCE: 0.1030 | Accuracy: 70.98% |
# End of validation epoch  15 | time:  0.92s | BCE: 0.0939 | Accuracy: 74.44% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 16 | 227/1137 batches | 17.98ms/ batch | BCE: 0.0991 | Accuracy: 71.28% |
# Epoch 16 | 454/1137 batches | 17.89ms/ batch | BCE: 0.0979 | Accuracy: 72.27% |
# Epoch 16 | 681/1137 batches | 17.86ms/ batch | BCE: 0.0990 | Accuracy: 71.82% |
# Epoch 16 | 908/1137 batches | 17.84ms/ batch | BCE: 0.0991 | Accuracy: 72.10% |
# Epoch 16 | 1135/1137 batches | 17.84ms/ batch | BCE: 0.0994 | Accuracy: 72.07% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  16 | time: 20.31s | BCE: 0.0994 | Accuracy: 72.08% |
# End of validation epoch  16 | time:  0.86s | BCE: 0.0932 | Accuracy: 74.58% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 17 | 227/1137 batches | 17.99ms/ batch | BCE: 0.0969 | Accuracy: 73.02% |
# Epoch 17 | 454/1137 batches | 17.91ms/ batch | BCE: 0.0971 | Accuracy: 72.80% |
# Epoch 17 | 681/1137 batches | 17.87ms/ batch | BCE: 0.0972 | Accuracy: 72.79% |
# Epoch 17 | 908/1137 batches | 17.86ms/ batch | BCE: 0.0984 | Accuracy: 72.31% |
# Epoch 17 | 1135/1137 batches | 17.89ms/ batch | BCE: 0.0981 | Accuracy: 72.43% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  17 | time: 20.36s | BCE: 0.0982 | Accuracy: 72.42% |
# End of validation epoch  17 | time:  1.10s | BCE: 0.0924 | Accuracy: 74.27% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 18 | 227/1137 batches | 18.10ms/ batch | BCE: 0.0942 | Accuracy: 74.16% |
# Epoch 18 | 454/1137 batches | 18.02ms/ batch | BCE: 0.0950 | Accuracy: 73.55% |
# Epoch 18 | 681/1137 batches | 17.98ms/ batch | BCE: 0.0953 | Accuracy: 73.27% |
# Epoch 18 | 908/1137 batches | 17.94ms/ batch | BCE: 0.0954 | Accuracy: 73.38% |
# Epoch 18 | 1135/1137 batches | 17.91ms/ batch | BCE: 0.0958 | Accuracy: 73.29% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  18 | time: 20.39s | BCE: 0.0957 | Accuracy: 73.32% |
# End of validation epoch  18 | time:  0.86s | BCE: 0.0928 | Accuracy: 74.93% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 19 | 227/1137 batches | 18.07ms/ batch | BCE: 0.0931 | Accuracy: 73.26% |
# Epoch 19 | 454/1137 batches | 17.97ms/ batch | BCE: 0.0924 | Accuracy: 74.07% |
# Epoch 19 | 681/1137 batches | 17.94ms/ batch | BCE: 0.0925 | Accuracy: 74.20% |
# Epoch 19 | 908/1137 batches | 17.92ms/ batch | BCE: 0.0933 | Accuracy: 73.98% |
# Epoch 19 | 1135/1137 batches | 17.93ms/ batch | BCE: 0.0938 | Accuracy: 73.80% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  19 | time: 20.41s | BCE: 0.0938 | Accuracy: 73.79% |
# End of validation epoch  19 | time:  0.88s | BCE: 0.0915 | Accuracy: 74.65% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 20 | 227/1137 batches | 18.02ms/ batch | BCE: 0.0941 | Accuracy: 73.72% |
# Epoch 20 | 454/1137 batches | 17.94ms/ batch | BCE: 0.0918 | Accuracy: 73.89% |
# Epoch 20 | 681/1137 batches | 17.91ms/ batch | BCE: 0.0923 | Accuracy: 74.01% |
# Epoch 20 | 908/1137 batches | 17.90ms/ batch | BCE: 0.0924 | Accuracy: 74.09% |
# Epoch 20 | 1135/1137 batches | 17.90ms/ batch | BCE: 0.0922 | Accuracy: 74.19% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  20 | time: 20.37s | BCE: 0.0922 | Accuracy: 74.16% |
# End of validation epoch  20 | time:  0.87s | BCE: 0.0917 | Accuracy: 75.24% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 21 | 227/1137 batches | 18.20ms/ batch | BCE: 0.0903 | Accuracy: 74.30% |
# Epoch 21 | 454/1137 batches | 18.11ms/ batch | BCE: 0.0905 | Accuracy: 74.42% |
# Epoch 21 | 681/1137 batches | 18.07ms/ batch | BCE: 0.0905 | Accuracy: 74.51% |
# Epoch 21 | 908/1137 batches | 18.06ms/ batch | BCE: 0.0907 | Accuracy: 74.37% |
# Epoch 21 | 1135/1137 batches | 18.04ms/ batch | BCE: 0.0904 | Accuracy: 74.56% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  21 | time: 20.53s | BCE: 0.0903 | Accuracy: 74.58% |
# End of validation epoch  21 | time:  1.06s | BCE: 0.0920 | Accuracy: 74.13% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 22 | 227/1137 batches | 17.97ms/ batch | BCE: 0.0888 | Accuracy: 75.09% |
# Epoch 22 | 454/1137 batches | 17.90ms/ batch | BCE: 0.0878 | Accuracy: 75.79% |
# Epoch 22 | 681/1137 batches | 17.87ms/ batch | BCE: 0.0882 | Accuracy: 75.45% |
# Epoch 22 | 908/1137 batches | 17.85ms/ batch | BCE: 0.0882 | Accuracy: 75.46% |
# Epoch 22 | 1135/1137 batches | 17.84ms/ batch | BCE: 0.0886 | Accuracy: 75.23% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  22 | time: 20.30s | BCE: 0.0887 | Accuracy: 75.18% |
# End of validation epoch  22 | time:  1.03s | BCE: 0.0907 | Accuracy: 74.65% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 23 | 227/1137 batches | 17.96ms/ batch | BCE: 0.0877 | Accuracy: 75.90% |
# Epoch 23 | 454/1137 batches | 17.87ms/ batch | BCE: 0.0861 | Accuracy: 76.39% |
# Epoch 23 | 681/1137 batches | 17.85ms/ batch | BCE: 0.0865 | Accuracy: 75.89% |
# Epoch 23 | 908/1137 batches | 17.84ms/ batch | BCE: 0.0860 | Accuracy: 76.10% |
# Epoch 23 | 1135/1137 batches | 17.83ms/ batch | BCE: 0.0859 | Accuracy: 76.17% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  23 | time: 20.30s | BCE: 0.0859 | Accuracy: 76.17% |
# End of validation epoch  23 | time:  0.85s | BCE: 0.0903 | Accuracy: 75.98% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 24 | 227/1137 batches | 18.14ms/ batch | BCE: 0.0838 | Accuracy: 76.96% |
# Epoch 24 | 454/1137 batches | 18.05ms/ batch | BCE: 0.0848 | Accuracy: 76.53% |
# Epoch 24 | 681/1137 batches | 17.97ms/ batch | BCE: 0.0850 | Accuracy: 76.55% |
# Epoch 24 | 908/1137 batches | 17.93ms/ batch | BCE: 0.0852 | Accuracy: 76.37% |
# Epoch 24 | 1135/1137 batches | 17.94ms/ batch | BCE: 0.0853 | Accuracy: 76.36% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  24 | time: 20.42s | BCE: 0.0853 | Accuracy: 76.35% |
# End of validation epoch  24 | time:  0.86s | BCE: 0.0903 | Accuracy: 75.00% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 25 | 227/1137 batches | 18.04ms/ batch | BCE: 0.0845 | Accuracy: 77.49% |
# Epoch 25 | 454/1137 batches | 17.97ms/ batch | BCE: 0.0819 | Accuracy: 77.46% |
# Epoch 25 | 681/1137 batches | 17.94ms/ batch | BCE: 0.0816 | Accuracy: 77.40% |
# Epoch 25 | 908/1137 batches | 17.92ms/ batch | BCE: 0.0811 | Accuracy: 77.57% |
# Epoch 25 | 1135/1137 batches | 17.91ms/ batch | BCE: 0.0817 | Accuracy: 77.43% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  25 | time: 20.38s | BCE: 0.0817 | Accuracy: 77.45% |
# End of validation epoch  25 | time:  0.95s | BCE: 0.0899 | Accuracy: 75.49% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 26 | 227/1137 batches | 18.08ms/ batch | BCE: 0.0777 | Accuracy: 78.61% |
# Epoch 26 | 454/1137 batches | 17.98ms/ batch | BCE: 0.0769 | Accuracy: 78.84% |
# Epoch 26 | 681/1137 batches | 17.94ms/ batch | BCE: 0.0795 | Accuracy: 78.06% |
# Epoch 26 | 908/1137 batches | 17.93ms/ batch | BCE: 0.0800 | Accuracy: 77.95% |
# Epoch 26 | 1135/1137 batches | 17.91ms/ batch | BCE: 0.0803 | Accuracy: 77.97% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  26 | time: 20.39s | BCE: 0.0803 | Accuracy: 77.97% |
# End of validation epoch  26 | time:  0.85s | BCE: 0.0895 | Accuracy: 75.56% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 27 | 227/1137 batches | 18.09ms/ batch | BCE: 0.0768 | Accuracy: 78.96% |
# Epoch 27 | 454/1137 batches | 18.03ms/ batch | BCE: 0.0779 | Accuracy: 78.58% |
# Epoch 27 | 681/1137 batches | 18.02ms/ batch | BCE: 0.0783 | Accuracy: 78.43% |
# Epoch 27 | 908/1137 batches | 18.01ms/ batch | BCE: 0.0784 | Accuracy: 78.27% |
# Epoch 27 | 1135/1137 batches | 18.01ms/ batch | BCE: 0.0782 | Accuracy: 78.32% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  27 | time: 20.50s | BCE: 0.0783 | Accuracy: 78.30% |
# End of validation epoch  27 | time:  0.91s | BCE: 0.0888 | Accuracy: 76.19% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 28 | 227/1137 batches | 18.10ms/ batch | BCE: 0.0741 | Accuracy: 79.63% |
# Epoch 28 | 454/1137 batches | 18.00ms/ batch | BCE: 0.0744 | Accuracy: 79.59% |
# Epoch 28 | 681/1137 batches | 17.95ms/ batch | BCE: 0.0753 | Accuracy: 79.49% |
# Epoch 28 | 908/1137 batches | 17.94ms/ batch | BCE: 0.0755 | Accuracy: 79.45% |
# Epoch 28 | 1135/1137 batches | 17.93ms/ batch | BCE: 0.0763 | Accuracy: 79.13% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  28 | time: 20.40s | BCE: 0.0763 | Accuracy: 79.14% |
# End of validation epoch  28 | time:  1.01s | BCE: 0.0891 | Accuracy: 75.77% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 29 | 227/1137 batches | 18.19ms/ batch | BCE: 0.0721 | Accuracy: 80.79% |
# Epoch 29 | 454/1137 batches | 18.01ms/ batch | BCE: 0.0730 | Accuracy: 80.42% |
# Epoch 29 | 681/1137 batches | 17.95ms/ batch | BCE: 0.0732 | Accuracy: 80.35% |
# Epoch 29 | 908/1137 batches | 17.91ms/ batch | BCE: 0.0738 | Accuracy: 80.04% |
# Epoch 29 | 1135/1137 batches | 17.90ms/ batch | BCE: 0.0745 | Accuracy: 79.82% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  29 | time: 20.37s | BCE: 0.0745 | Accuracy: 79.81% |
# End of validation epoch  29 | time:  0.88s | BCE: 0.0880 | Accuracy: 75.28% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 30 | 227/1137 batches | 18.15ms/ batch | BCE: 0.0725 | Accuracy: 80.18% |
# Epoch 30 | 454/1137 batches | 18.07ms/ batch | BCE: 0.0717 | Accuracy: 80.25% |
# Epoch 30 | 681/1137 batches | 18.02ms/ batch | BCE: 0.0720 | Accuracy: 80.22% |
# Epoch 30 | 908/1137 batches | 17.98ms/ batch | BCE: 0.0723 | Accuracy: 80.12% |
# Epoch 30 | 1135/1137 batches | 17.96ms/ batch | BCE: 0.0728 | Accuracy: 80.03% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  30 | time: 20.44s | BCE: 0.0729 | Accuracy: 80.01% |
# End of validation epoch  30 | time:  1.05s | BCE: 0.0881 | Accuracy: 75.52% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 31 | 227/1137 batches | 18.08ms/ batch | BCE: 0.0707 | Accuracy: 80.84% |
# Epoch 31 | 454/1137 batches | 18.03ms/ batch | BCE: 0.0696 | Accuracy: 81.41% |
# Epoch 31 | 681/1137 batches | 18.01ms/ batch | BCE: 0.0697 | Accuracy: 81.47% |
# Epoch 31 | 908/1137 batches | 18.01ms/ batch | BCE: 0.0699 | Accuracy: 81.21% |
# Epoch 31 | 1135/1137 batches | 18.00ms/ batch | BCE: 0.0703 | Accuracy: 81.10% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  31 | time: 20.49s | BCE: 0.0703 | Accuracy: 81.09% |
# End of validation epoch  31 | time:  1.02s | BCE: 0.0875 | Accuracy: 76.15% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 32 | 227/1137 batches | 18.00ms/ batch | BCE: 0.0660 | Accuracy: 82.07% |
# Epoch 32 | 454/1137 batches | 17.96ms/ batch | BCE: 0.0659 | Accuracy: 81.96% |
# Epoch 32 | 681/1137 batches | 17.94ms/ batch | BCE: 0.0670 | Accuracy: 81.86% |
# Epoch 32 | 908/1137 batches | 17.93ms/ batch | BCE: 0.0675 | Accuracy: 81.71% |
# Epoch 32 | 1135/1137 batches | 17.91ms/ batch | BCE: 0.0681 | Accuracy: 81.61% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  32 | time: 20.39s | BCE: 0.0681 | Accuracy: 81.61% |
# End of validation epoch  32 | time:  0.88s | BCE: 0.0887 | Accuracy: 75.56% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 33 | 227/1137 batches | 18.08ms/ batch | BCE: 0.0631 | Accuracy: 83.24% |
# Epoch 33 | 454/1137 batches | 17.99ms/ batch | BCE: 0.0651 | Accuracy: 82.21% |
# Epoch 33 | 681/1137 batches | 17.95ms/ batch | BCE: 0.0650 | Accuracy: 82.21% |
# Epoch 33 | 908/1137 batches | 17.93ms/ batch | BCE: 0.0648 | Accuracy: 82.31% |
# Epoch 33 | 1135/1137 batches | 17.92ms/ batch | BCE: 0.0652 | Accuracy: 82.35% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  33 | time: 20.39s | BCE: 0.0652 | Accuracy: 82.33% |
# End of validation epoch  33 | time:  0.87s | BCE: 0.0878 | Accuracy: 75.98% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 34 | 227/1137 batches | 18.10ms/ batch | BCE: 0.0611 | Accuracy: 83.70% |
# Epoch 34 | 454/1137 batches | 18.01ms/ batch | BCE: 0.0617 | Accuracy: 83.58% |
# Epoch 34 | 681/1137 batches | 17.98ms/ batch | BCE: 0.0618 | Accuracy: 83.72% |
# Epoch 34 | 908/1137 batches | 17.99ms/ batch | BCE: 0.0624 | Accuracy: 83.56% |
# Epoch 34 | 1135/1137 batches | 17.97ms/ batch | BCE: 0.0631 | Accuracy: 83.35% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  34 | time: 20.45s | BCE: 0.0631 | Accuracy: 83.34% |
# End of validation epoch  34 | time:  0.86s | BCE: 0.0871 | Accuracy: 76.54% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 35 | 227/1137 batches | 18.04ms/ batch | BCE: 0.0570 | Accuracy: 84.80% |
# Epoch 35 | 454/1137 batches | 17.95ms/ batch | BCE: 0.0603 | Accuracy: 83.99% |
# Epoch 35 | 681/1137 batches | 17.93ms/ batch | BCE: 0.0598 | Accuracy: 84.15% |
# Epoch 35 | 908/1137 batches | 17.92ms/ batch | BCE: 0.0605 | Accuracy: 83.75% |
# Epoch 35 | 1135/1137 batches | 17.91ms/ batch | BCE: 0.0609 | Accuracy: 83.58% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  35 | time: 20.39s | BCE: 0.0609 | Accuracy: 83.58% |
# End of validation epoch  35 | time:  0.87s | BCE: 0.0876 | Accuracy: 76.26% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 36 | 227/1137 batches | 18.11ms/ batch | BCE: 0.0583 | Accuracy: 84.71% |
# Epoch 36 | 454/1137 batches | 18.01ms/ batch | BCE: 0.0584 | Accuracy: 84.46% |
# Epoch 36 | 681/1137 batches | 17.99ms/ batch | BCE: 0.0584 | Accuracy: 84.59% |
# Epoch 36 | 908/1137 batches | 17.96ms/ batch | BCE: 0.0589 | Accuracy: 84.36% |
# Epoch 36 | 1135/1137 batches | 17.96ms/ batch | BCE: 0.0593 | Accuracy: 84.24% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  36 | time: 20.44s | BCE: 0.0593 | Accuracy: 84.22% |
# End of validation epoch  36 | time:  0.88s | BCE: 0.0872 | Accuracy: 76.64% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 37 | 227/1137 batches | 18.02ms/ batch | BCE: 0.0546 | Accuracy: 85.26% |
# Epoch 37 | 454/1137 batches | 17.93ms/ batch | BCE: 0.0560 | Accuracy: 85.33% |
# Epoch 37 | 681/1137 batches | 17.90ms/ batch | BCE: 0.0560 | Accuracy: 85.32% |
# Epoch 37 | 908/1137 batches | 18.05ms/ batch | BCE: 0.0566 | Accuracy: 85.07% |
# Epoch 37 | 1135/1137 batches | 19.62ms/ batch | BCE: 0.0571 | Accuracy: 84.98% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  37 | time: 22.39s | BCE: 0.0571 | Accuracy: 84.98% |
# End of validation epoch  37 | time:  1.74s | BCE: 0.0877 | Accuracy: 76.15% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 38 | 227/1137 batches | 47.59ms/ batch | BCE: 0.0515 | Accuracy: 86.76% |
# Epoch 38 | 454/1137 batches | 47.45ms/ batch | BCE: 0.0536 | Accuracy: 85.88% |
# Epoch 38 | 681/1137 batches | 47.47ms/ batch | BCE: 0.0534 | Accuracy: 86.03% |
# Epoch 38 | 908/1137 batches | 47.36ms/ batch | BCE: 0.0543 | Accuracy: 85.69% |
# Epoch 38 | 1135/1137 batches | 47.37ms/ batch | BCE: 0.0546 | Accuracy: 85.61% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  38 | time: 53.89s | BCE: 0.0545 | Accuracy: 85.62% |
# End of validation epoch  38 | time:  1.74s | BCE: 0.0879 | Accuracy: 75.73% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 39 | 227/1137 batches | 47.64ms/ batch | BCE: 0.0515 | Accuracy: 86.45% |
# Epoch 39 | 454/1137 batches | 45.64ms/ batch | BCE: 0.0521 | Accuracy: 86.26% |
# Epoch 39 | 681/1137 batches | 45.24ms/ batch | BCE: 0.0527 | Accuracy: 86.20% |
# Epoch 39 | 908/1137 batches | 40.50ms/ batch | BCE: 0.0530 | Accuracy: 86.06% |
# Epoch 39 | 1135/1137 batches | 40.98ms/ batch | BCE: 0.0530 | Accuracy: 86.13% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  39 | time: 46.62s | BCE: 0.0530 | Accuracy: 86.13% |
# End of validation epoch  39 | time:  1.73s | BCE: 0.0872 | Accuracy: 76.92% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 40 | 227/1137 batches | 47.99ms/ batch | BCE: 0.0483 | Accuracy: 87.16% |
# Epoch 40 | 454/1137 batches | 47.94ms/ batch | BCE: 0.0503 | Accuracy: 86.55% |
# Epoch 40 | 681/1137 batches | 46.66ms/ batch | BCE: 0.0503 | Accuracy: 86.74% |
# Epoch 40 | 908/1137 batches | 47.00ms/ batch | BCE: 0.0508 | Accuracy: 86.66% |
# Epoch 40 | 1135/1137 batches | 47.12ms/ batch | BCE: 0.0511 | Accuracy: 86.59% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  40 | time: 53.60s | BCE: 0.0511 | Accuracy: 86.60% |
# End of validation epoch  40 | time:  1.74s | BCE: 0.0876 | Accuracy: 76.43% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 41 | 227/1137 batches | 43.28ms/ batch | BCE: 0.0476 | Accuracy: 88.08% |
# Epoch 41 | 454/1137 batches | 44.99ms/ batch | BCE: 0.0487 | Accuracy: 87.65% |
# Epoch 41 | 681/1137 batches | 38.40ms/ batch | BCE: 0.0492 | Accuracy: 87.18% |
# Epoch 41 | 908/1137 batches | 40.00ms/ batch | BCE: 0.0494 | Accuracy: 87.18% |
# Epoch 41 | 1135/1137 batches | 41.52ms/ batch | BCE: 0.0491 | Accuracy: 87.26% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  41 | time: 47.25s | BCE: 0.0491 | Accuracy: 87.25% |
# End of validation epoch  41 | time:  1.69s | BCE: 0.0891 | Accuracy: 76.36% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 42 | 227/1137 batches | 47.45ms/ batch | BCE: 0.0472 | Accuracy: 87.42% |
# Epoch 42 | 454/1137 batches | 45.66ms/ batch | BCE: 0.0464 | Accuracy: 87.79% |
# Epoch 42 | 681/1137 batches | 44.70ms/ batch | BCE: 0.0472 | Accuracy: 87.56% |
# Epoch 42 | 908/1137 batches | 44.46ms/ batch | BCE: 0.0475 | Accuracy: 87.57% |
# Epoch 42 | 1135/1137 batches | 44.68ms/ batch | BCE: 0.0473 | Accuracy: 87.53% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  42 | time: 50.82s | BCE: 0.0473 | Accuracy: 87.54% |
# End of validation epoch  42 | time:  1.70s | BCE: 0.0883 | Accuracy: 76.05% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 43 | 227/1137 batches | 47.88ms/ batch | BCE: 0.0448 | Accuracy: 88.63% |
# Epoch 43 | 454/1137 batches | 45.85ms/ batch | BCE: 0.0448 | Accuracy: 88.84% |
# Epoch 43 | 681/1137 batches | 39.30ms/ batch | BCE: 0.0447 | Accuracy: 88.82% |
# Epoch 43 | 908/1137 batches | 41.46ms/ batch | BCE: 0.0450 | Accuracy: 88.65% |
# Epoch 43 | 1135/1137 batches | 42.64ms/ batch | BCE: 0.0453 | Accuracy: 88.45% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  43 | time: 48.52s | BCE: 0.0453 | Accuracy: 88.44% |
# End of validation epoch  43 | time:  1.72s | BCE: 0.0880 | Accuracy: 76.68% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 44 | 227/1137 batches | 47.83ms/ batch | BCE: 0.0406 | Accuracy: 90.11% |
# Epoch 44 | 454/1137 batches | 45.42ms/ batch | BCE: 0.0411 | Accuracy: 89.93% |
# Epoch 44 | 681/1137 batches | 44.61ms/ batch | BCE: 0.0415 | Accuracy: 89.74% |
# Epoch 44 | 908/1137 batches | 44.20ms/ batch | BCE: 0.0420 | Accuracy: 89.54% |
# Epoch 44 | 1135/1137 batches | 43.96ms/ batch | BCE: 0.0427 | Accuracy: 89.23% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  44 | time: 50.01s | BCE: 0.0427 | Accuracy: 89.23% |
# End of validation epoch  44 | time:  1.69s | BCE: 0.0878 | Accuracy: 77.03% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 45 | 227/1137 batches | 43.17ms/ batch | BCE: 0.0406 | Accuracy: 89.58% |
# Epoch 45 | 454/1137 batches | 34.80ms/ batch | BCE: 0.0397 | Accuracy: 89.90% |
# Epoch 45 | 681/1137 batches | 37.35ms/ batch | BCE: 0.0404 | Accuracy: 89.73% |
# Epoch 45 | 908/1137 batches | 39.95ms/ batch | BCE: 0.0401 | Accuracy: 90.01% |
# Epoch 45 | 1135/1137 batches | 41.47ms/ batch | BCE: 0.0408 | Accuracy: 89.82% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  45 | time: 47.19s | BCE: 0.0408 | Accuracy: 89.82% |
# End of validation epoch  45 | time:  1.70s | BCE: 0.0893 | Accuracy: 75.91% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 46 | 227/1137 batches | 45.13ms/ batch | BCE: 0.0382 | Accuracy: 90.20% |
# Epoch 46 | 454/1137 batches | 46.25ms/ batch | BCE: 0.0369 | Accuracy: 90.73% |
# Epoch 46 | 681/1137 batches | 46.71ms/ batch | BCE: 0.0372 | Accuracy: 90.68% |
# Epoch 46 | 908/1137 batches | 46.86ms/ batch | BCE: 0.0379 | Accuracy: 90.47% |
# Epoch 46 | 1135/1137 batches | 46.90ms/ batch | BCE: 0.0388 | Accuracy: 90.26% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  46 | time: 53.34s | BCE: 0.0388 | Accuracy: 90.26% |
# End of validation epoch  46 | time:  1.74s | BCE: 0.0890 | Accuracy: 76.50% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 47 | 227/1137 batches | 43.73ms/ batch | BCE: 0.0350 | Accuracy: 91.19% |
# Epoch 47 | 454/1137 batches | 45.71ms/ batch | BCE: 0.0356 | Accuracy: 91.21% |
# Epoch 47 | 681/1137 batches | 46.43ms/ batch | BCE: 0.0363 | Accuracy: 91.05% |
# Epoch 47 | 908/1137 batches | 46.68ms/ batch | BCE: 0.0370 | Accuracy: 90.83% |
# Epoch 47 | 1135/1137 batches | 46.91ms/ batch | BCE: 0.0373 | Accuracy: 90.66% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  47 | time: 53.37s | BCE: 0.0373 | Accuracy: 90.66% |
# End of validation epoch  47 | time:  1.65s | BCE: 0.0888 | Accuracy: 76.96% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 48 | 227/1137 batches | 48.01ms/ batch | BCE: 0.0353 | Accuracy: 91.59% |
# Epoch 48 | 454/1137 batches | 47.94ms/ batch | BCE: 0.0358 | Accuracy: 91.22% |
# Epoch 48 | 681/1137 batches | 47.85ms/ batch | BCE: 0.0362 | Accuracy: 91.28% |
# Epoch 48 | 908/1137 batches | 47.33ms/ batch | BCE: 0.0362 | Accuracy: 91.25% |
# Epoch 48 | 1135/1137 batches | 42.90ms/ batch | BCE: 0.0360 | Accuracy: 91.34% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  48 | time: 48.75s | BCE: 0.0360 | Accuracy: 91.35% |
# End of validation epoch  48 | time:  1.57s | BCE: 0.0899 | Accuracy: 76.19% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 49 | 227/1137 batches | 47.99ms/ batch | BCE: 0.0333 | Accuracy: 91.87% |
# Epoch 49 | 454/1137 batches | 47.64ms/ batch | BCE: 0.0340 | Accuracy: 91.85% |
# Epoch 49 | 681/1137 batches | 47.43ms/ batch | BCE: 0.0342 | Accuracy: 91.75% |
# Epoch 49 | 908/1137 batches | 47.40ms/ batch | BCE: 0.0345 | Accuracy: 91.57% |
# Epoch 49 | 1135/1137 batches | 47.25ms/ batch | BCE: 0.0349 | Accuracy: 91.51% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  49 | time: 53.74s | BCE: 0.0349 | Accuracy: 91.52% |
# End of validation epoch  49 | time:  1.71s | BCE: 0.0897 | Accuracy: 76.71% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 50 | 227/1137 batches | 47.96ms/ batch | BCE: 0.0322 | Accuracy: 92.00% |
# Epoch 50 | 454/1137 batches | 47.76ms/ batch | BCE: 0.0320 | Accuracy: 92.29% |
# Epoch 50 | 681/1137 batches | 47.65ms/ batch | BCE: 0.0324 | Accuracy: 92.12% |
# Epoch 50 | 908/1137 batches | 43.06ms/ batch | BCE: 0.0327 | Accuracy: 92.10% |
# Epoch 50 | 1135/1137 batches | 41.75ms/ batch | BCE: 0.0329 | Accuracy: 91.98% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  50 | time: 47.50s | BCE: 0.0329 | Accuracy: 92.00% |
# End of validation epoch  50 | time:  1.77s | BCE: 0.0895 | Accuracy: 76.89% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Model Analysis

# %%
plt.figure(figsize=(10, 5))
plt.plot(log['train_loss'], '--', color=(1,0,0,0.8), label='BCE_LOSS (Train)')
plt.plot(log['valid_loss'], '--', color=(0,0,1,0.8), label='BCE_LOSS (Validation)')
plt.tight_layout()
plt.legend(loc="best")
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(log['train_accu'], '--', color=(1,0,0,0.8), label='Accuracy (Train)')
plt.plot(log['valid_accu'], '--', color=(0,0,1,0.8), label='Accuracy (Validation)')
plt.tight_layout()
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ## Test Model on test set

# %%
from Train import validate_test
import torch

# %%
txtModel = Model()
txtModel.cuda().load_state_dict(torch.load(Settings.model_save_folder + 'model.h5'))
validate_test(model=txtModel, epoch=0, use_loader=test_loader)
# Out:
# End of validation epoch   0 | time:  1.73s | BCE: 0.0874 | Accuracy: 76.96% |
# ---------------------------------------------------------------------------------------------------
# (0.08736152586142917, 0.7695804195804195)

# %% [markdown]
# ## Confusion Matrix

# %%
from Evaluate import Evaluator
model = Model()
evaluator = Evaluator(model, "model.h5")

# %%
evaluator.record_matrix(test_loader, "textCNNconfusion.json")
# Out:
# End of Matrix Record, Save file in ../LogSave/textCNNconfusion.json
# ---------------------------------------------------------------------------------------------------

# %%
import numpy as np
import pandas as pd
import seaborn as sn

# %%
matrix = np.zeros((Settings.class_num, Settings.class_num))
with open(Settings.log_save_folder + 'textCNNconfusion.json', 'r') as f:
    tuple_list = json.load(f)

# %%
for point in tuple_list:
    i, j = point  # i is predict, j is real, record 100 point for each label
    matrix[i][j] += 1

# %%
matrix /= sum(matrix)
matrix = pd.DataFrame(matrix, index = [evaluator.index_to_label.get(str(i+1)) for i in range(Settings.class_num)],
                  columns = [evaluator.index_to_label.get(str(i+1)) for i in range(Settings.class_num)],)

# %%
plt.figure(figsize=(12, 8))
plt.title('Text CNN Model')
sn.heatmap(matrix, annot=True,)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Conclusion
# Current model has 76% accuracy on "chunk test"

# %% [markdown]
# # Test model on original set

# %%
import csv

csv_file = open(Settings.data_path, "r")
csv_reader = csv.reader(csv_file)

count = 0
right_count = 0
for line in csv_reader:
    label, doc = line
    pred_label, score = evaluator.label_predict(doc)
    count += 1
    if pred_label == label:
        right_count += 1
    if count > 1000:
        break

csv_file.close()
print(count, right_count)
# Out:
# 1001 954

# %%
right_count/ count
# Out:
# 0.9530469530469531

# %% [markdown]
# # Current Model Result
#
# - 95% on full length document
# - 77% on chunks

# %% [markdown]
# # Train Model Use Full Set

# %%
# Dataloaders
e_train_loader = torch_dataset_loader(Settings.e_train_path, Settings.batch_size, True, Settings.kwargs)
e_validation_loader = torch_dataset_loader(Settings.e_valid_path, Settings.batch_size, False, Settings.kwargs)
e_test_loader = torch_dataset_loader(Settings.e_test_path, Settings.batch_size, False, Settings.kwargs)

# %%
fulltxtModel = Model()
e_log = main_train(fulltxtModel, e_train_loader, e_validation_loader, "e_train.json", "e_model.h5")
# Out:
# Epoch  1 | 932/4661 batches | 17.98ms/ batch | BCE: 0.1934 | Accuracy: 43.89% |
# Epoch  1 | 1864/4661 batches | 17.93ms/ batch | BCE: 0.1723 | Accuracy: 50.82% |
# Epoch  1 | 2796/4661 batches | 17.94ms/ batch | BCE: 0.1604 | Accuracy: 54.51% |
# Epoch  1 | 3728/4661 batches | 17.95ms/ batch | BCE: 0.1525 | Accuracy: 56.96% |
# Epoch  1 | 4660/4661 batches | 17.97ms/ batch | BCE: 0.1463 | Accuracy: 58.88% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   1 | time: 83.78s | BCE: 0.1463 | Accuracy: 58.88% |
# End of validation epoch   1 | time:  4.38s | BCE: 0.0956 | Accuracy: 72.89% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  2 | 932/4661 batches | 17.97ms/ batch | BCE: 0.1149 | Accuracy: 68.10% |
# Epoch  2 | 1864/4661 batches | 17.92ms/ batch | BCE: 0.1122 | Accuracy: 69.16% |
# Epoch  2 | 2796/4661 batches | 17.91ms/ batch | BCE: 0.1109 | Accuracy: 69.59% |
# Epoch  2 | 3728/4661 batches | 17.89ms/ batch | BCE: 0.1100 | Accuracy: 69.85% |
# Epoch  2 | 4660/4661 batches | 17.88ms/ batch | BCE: 0.1088 | Accuracy: 70.21% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   2 | time: 83.35s | BCE: 0.1088 | Accuracy: 70.22% |
# End of validation epoch   2 | time:  3.32s | BCE: 0.0842 | Accuracy: 76.98% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  3 | 932/4661 batches | 17.96ms/ batch | BCE: 0.1016 | Accuracy: 72.24% |
# Epoch  3 | 1864/4661 batches | 21.29ms/ batch | BCE: 0.1004 | Accuracy: 72.45% |
# Epoch  3 | 2796/4661 batches | 28.93ms/ batch | BCE: 0.1001 | Accuracy: 72.69% |

# %%
plt.figure(figsize=(10, 5))
plt.plot(e_log['train_loss'], '--', color=(1,0,0,0.8), label='BCE_LOSS (Train)')
plt.plot(e_log['valid_loss'], '--', color=(0,0,1,0.8), label='BCE_LOSS (Validation)')
plt.tight_layout()
plt.legend(loc="best")
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(e_log['train_accu'], '--', color=(1,0,0,0.8), label='Accuracy (Train)')
plt.plot(e_log['valid_accu'], '--', color=(0,0,1,0.8), label='Accuracy (Validation)')
plt.tight_layout()
plt.legend(loc="best")
plt.show()

# %% [markdown]
# As seen in picture, there is overfitting

# %%
fulltxtModel = Model()
fulltxtModel.cuda().load_state_dict(torch.load(Settings.model_save_folder + 'e_model.h5'))
validate_test(model=fulltxtModel, epoch=0, use_loader=e_test_loader)

# %% [markdown]
# The model has 80% accuracy over test set

# %%
full_evaluator = Evaluator(fulltxtModel, "e_model.h5")

# %%
full_evaluator.record_matrix(e_test_loader, "textCNNconfusion-full.json")

# %%
matrix = np.zeros((Settings.class_num, Settings.class_num))
with open(Settings.log_save_folder + 'textCNNconfusion-full.json', 'r') as f:
    tuple_list = json.load(f)
for point in tuple_list:
    i, j = point  # i is predict, j is real, record 100 point for each label
    matrix[i][j] += 1
matrix /= sum(matrix)
matrix = pd.DataFrame(matrix, index = [evaluator.index_to_label.get(str(i+1)) for i in range(Settings.class_num)],
                  columns = [evaluator.index_to_label.get(str(i+1)) for i in range(Settings.class_num)],)
plt.figure(figsize=(12, 8))
plt.title('Text CNN Model on Full Data')
sn.heatmap(matrix, annot=True,)
plt.tight_layout()
plt.show()
