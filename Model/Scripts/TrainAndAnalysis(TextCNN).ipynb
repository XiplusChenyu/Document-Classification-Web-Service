# %% [markdown]
# # Train and Data Analysis
#
# - Use Jupyter Notebook for training
# - Train on GCP to use Cuda

# %%
from Settings import Settings
Settings.learning_rate = 1e-4
Settings.epoch_num = 50
Settings.print_count = 5  # print 5 count for 1 epoch
Settings.batch_size = 10
Settings.drop_out = 0.6

# %%
from DataLoader import torch_dataset_loader
from TextCNN import Model
from Train import main_train

import json
import matplotlib.pyplot as plt

# %%
# Dataloaders
train_loader = torch_dataset_loader(Settings.train_path, Settings.batch_size, True, Settings.kwargs)
validation_loader = torch_dataset_loader(Settings.valid_path, Settings.batch_size, False, Settings.kwargs)
test_loader = torch_dataset_loader(Settings.test_path, Settings.batch_size, False, Settings.kwargs)

# %% [markdown]
# ## Train Text CNN Model

# %%
txtModel = Model()
log = main_train(txtModel, train_loader, validation_loader, "train.json", "model.h5")
# Out:
# Epoch  1 | 212/1060 batches | 20.20ms/ batch | BCE: 0.3012 | Accuracy: 12.22% |
# Epoch  1 | 424/1060 batches | 17.37ms/ batch | BCE: 0.2909 | Accuracy: 14.06% |
# Epoch  1 | 636/1060 batches | 16.43ms/ batch | BCE: 0.2837 | Accuracy: 15.97% |
# Epoch  1 | 848/1060 batches | 15.96ms/ batch | BCE: 0.2770 | Accuracy: 17.10% |
# Epoch  1 | 1060/1060 batches | 15.68ms/ batch | BCE: 0.2709 | Accuracy: 18.08% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   1 | time: 16.64s | BCE: 0.2709 | Accuracy: 18.08% |
# End of validation epoch   1 | time:  0.51s | BCE: 0.1955 | Accuracy: 49.66% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  2 | 212/1060 batches | 14.82ms/ batch | BCE: 0.2300 | Accuracy: 27.64% |
# Epoch  2 | 424/1060 batches | 14.74ms/ batch | BCE: 0.2274 | Accuracy: 28.68% |
# Epoch  2 | 636/1060 batches | 14.71ms/ batch | BCE: 0.2241 | Accuracy: 29.94% |
# Epoch  2 | 848/1060 batches | 14.70ms/ batch | BCE: 0.2213 | Accuracy: 31.14% |
# Epoch  2 | 1060/1060 batches | 14.69ms/ batch | BCE: 0.2177 | Accuracy: 32.49% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   2 | time: 15.59s | BCE: 0.2177 | Accuracy: 32.49% |
# End of validation epoch   2 | time:  0.58s | BCE: 0.1633 | Accuracy: 56.20% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  3 | 212/1060 batches | 14.70ms/ batch | BCE: 0.1925 | Accuracy: 39.67% |
# Epoch  3 | 424/1060 batches | 14.63ms/ batch | BCE: 0.1893 | Accuracy: 40.52% |
# Epoch  3 | 636/1060 batches | 14.60ms/ batch | BCE: 0.1879 | Accuracy: 40.83% |
# Epoch  3 | 848/1060 batches | 14.59ms/ batch | BCE: 0.1858 | Accuracy: 41.76% |
# Epoch  3 | 1060/1060 batches | 14.57ms/ batch | BCE: 0.1849 | Accuracy: 42.44% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   3 | time: 15.47s | BCE: 0.1849 | Accuracy: 42.44% |
# End of validation epoch   3 | time:  0.48s | BCE: 0.1440 | Accuracy: 61.32% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  4 | 212/1060 batches | 14.69ms/ batch | BCE: 0.1683 | Accuracy: 48.96% |
# Epoch  4 | 424/1060 batches | 14.63ms/ batch | BCE: 0.1677 | Accuracy: 50.14% |
# Epoch  4 | 636/1060 batches | 14.66ms/ batch | BCE: 0.1684 | Accuracy: 50.05% |
# Epoch  4 | 848/1060 batches | 14.67ms/ batch | BCE: 0.1673 | Accuracy: 50.24% |
# Epoch  4 | 1060/1060 batches | 14.67ms/ batch | BCE: 0.1668 | Accuracy: 50.43% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   4 | time: 15.58s | BCE: 0.1668 | Accuracy: 50.43% |
# End of validation epoch   4 | time:  0.48s | BCE: 0.1340 | Accuracy: 63.50% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  5 | 212/1060 batches | 14.67ms/ batch | BCE: 0.1585 | Accuracy: 52.59% |
# Epoch  5 | 424/1060 batches | 14.58ms/ batch | BCE: 0.1555 | Accuracy: 54.20% |
# Epoch  5 | 636/1060 batches | 14.55ms/ batch | BCE: 0.1552 | Accuracy: 54.21% |
# Epoch  5 | 848/1060 batches | 14.54ms/ batch | BCE: 0.1541 | Accuracy: 54.28% |
# Epoch  5 | 1060/1060 batches | 14.53ms/ batch | BCE: 0.1542 | Accuracy: 54.13% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   5 | time: 15.42s | BCE: 0.1542 | Accuracy: 54.13% |
# End of validation epoch   5 | time:  0.59s | BCE: 0.1292 | Accuracy: 63.42% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch  6 | 212/1060 batches | 14.62ms/ batch | BCE: 0.1481 | Accuracy: 56.70% |
# Epoch  6 | 424/1060 batches | 14.56ms/ batch | BCE: 0.1466 | Accuracy: 57.05% |
# Epoch  6 | 636/1060 batches | 14.56ms/ batch | BCE: 0.1457 | Accuracy: 57.25% |
# Epoch  6 | 848/1060 batches | 14.57ms/ batch | BCE: 0.1465 | Accuracy: 56.84% |
# Epoch  6 | 1060/1060 batches | 14.57ms/ batch | BCE: 0.1463 | Accuracy: 57.03% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   6 | time: 15.47s | BCE: 0.1463 | Accuracy: 57.03% |
# End of validation epoch   6 | time:  0.49s | BCE: 0.1226 | Accuracy: 67.22% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  7 | 212/1060 batches | 14.65ms/ batch | BCE: 0.1373 | Accuracy: 60.94% |
# Epoch  7 | 424/1060 batches | 14.57ms/ batch | BCE: 0.1371 | Accuracy: 60.33% |
# Epoch  7 | 636/1060 batches | 14.54ms/ batch | BCE: 0.1383 | Accuracy: 60.20% |
# Epoch  7 | 848/1060 batches | 14.53ms/ batch | BCE: 0.1385 | Accuracy: 60.05% |
# Epoch  7 | 1060/1060 batches | 14.52ms/ batch | BCE: 0.1389 | Accuracy: 60.02% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   7 | time: 15.41s | BCE: 0.1389 | Accuracy: 60.02% |
# End of validation epoch   7 | time:  0.54s | BCE: 0.1192 | Accuracy: 68.42% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  8 | 212/1060 batches | 14.82ms/ batch | BCE: 0.1316 | Accuracy: 61.04% |
# Epoch  8 | 424/1060 batches | 14.67ms/ batch | BCE: 0.1317 | Accuracy: 61.72% |
# Epoch  8 | 636/1060 batches | 14.61ms/ batch | BCE: 0.1323 | Accuracy: 61.60% |
# Epoch  8 | 848/1060 batches | 14.58ms/ batch | BCE: 0.1320 | Accuracy: 61.73% |
# Epoch  8 | 1060/1060 batches | 14.58ms/ batch | BCE: 0.1321 | Accuracy: 61.65% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   8 | time: 15.48s | BCE: 0.1321 | Accuracy: 61.65% |
# End of validation epoch   8 | time:  0.52s | BCE: 0.1164 | Accuracy: 69.02% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  9 | 212/1060 batches | 14.79ms/ batch | BCE: 0.1262 | Accuracy: 63.58% |
# Epoch  9 | 424/1060 batches | 14.69ms/ batch | BCE: 0.1270 | Accuracy: 62.74% |
# Epoch  9 | 636/1060 batches | 14.66ms/ batch | BCE: 0.1282 | Accuracy: 62.85% |
# Epoch  9 | 848/1060 batches | 14.65ms/ batch | BCE: 0.1291 | Accuracy: 62.92% |
# Epoch  9 | 1060/1060 batches | 14.64ms/ batch | BCE: 0.1286 | Accuracy: 63.08% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   9 | time: 15.55s | BCE: 0.1286 | Accuracy: 63.08% |
# End of validation epoch   9 | time:  0.56s | BCE: 0.1138 | Accuracy: 69.47% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 10 | 212/1060 batches | 14.66ms/ batch | BCE: 0.1234 | Accuracy: 63.96% |
# Epoch 10 | 424/1060 batches | 14.58ms/ batch | BCE: 0.1207 | Accuracy: 65.09% |
# Epoch 10 | 636/1060 batches | 14.55ms/ batch | BCE: 0.1215 | Accuracy: 65.08% |
# Epoch 10 | 848/1060 batches | 14.53ms/ batch | BCE: 0.1227 | Accuracy: 64.69% |
# Epoch 10 | 1060/1060 batches | 14.52ms/ batch | BCE: 0.1235 | Accuracy: 64.52% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  10 | time: 15.42s | BCE: 0.1235 | Accuracy: 64.52% |
# End of validation epoch  10 | time:  0.51s | BCE: 0.1128 | Accuracy: 70.45% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 11 | 212/1060 batches | 14.77ms/ batch | BCE: 0.1204 | Accuracy: 65.14% |
# Epoch 11 | 424/1060 batches | 14.67ms/ batch | BCE: 0.1186 | Accuracy: 65.66% |
# Epoch 11 | 636/1060 batches | 14.63ms/ batch | BCE: 0.1189 | Accuracy: 65.80% |
# Epoch 11 | 848/1060 batches | 14.62ms/ batch | BCE: 0.1191 | Accuracy: 65.59% |
# Epoch 11 | 1060/1060 batches | 14.62ms/ batch | BCE: 0.1203 | Accuracy: 65.30% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  11 | time: 15.52s | BCE: 0.1203 | Accuracy: 65.30% |
# End of validation epoch  11 | time:  0.60s | BCE: 0.1108 | Accuracy: 69.59% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 12 | 212/1060 batches | 14.69ms/ batch | BCE: 0.1145 | Accuracy: 67.64% |
# Epoch 12 | 424/1060 batches | 14.61ms/ batch | BCE: 0.1148 | Accuracy: 67.67% |
# Epoch 12 | 636/1060 batches | 14.59ms/ batch | BCE: 0.1130 | Accuracy: 68.22% |
# Epoch 12 | 848/1060 batches | 14.58ms/ batch | BCE: 0.1147 | Accuracy: 67.59% |
# Epoch 12 | 1060/1060 batches | 14.56ms/ batch | BCE: 0.1164 | Accuracy: 67.08% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  12 | time: 15.46s | BCE: 0.1164 | Accuracy: 67.08% |
# End of validation epoch  12 | time:  0.50s | BCE: 0.1088 | Accuracy: 71.58% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 13 | 212/1060 batches | 14.77ms/ batch | BCE: 0.1097 | Accuracy: 69.58% |
# Epoch 13 | 424/1060 batches | 14.69ms/ batch | BCE: 0.1111 | Accuracy: 68.92% |
# Epoch 13 | 636/1060 batches | 14.66ms/ batch | BCE: 0.1119 | Accuracy: 68.68% |
# Epoch 13 | 848/1060 batches | 14.64ms/ batch | BCE: 0.1129 | Accuracy: 68.20% |
# Epoch 13 | 1060/1060 batches | 14.63ms/ batch | BCE: 0.1142 | Accuracy: 67.92% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  13 | time: 15.53s | BCE: 0.1142 | Accuracy: 67.92% |
# End of validation epoch  13 | time:  0.52s | BCE: 0.1090 | Accuracy: 71.05% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 14 | 212/1060 batches | 14.78ms/ batch | BCE: 0.1085 | Accuracy: 69.58% |
# Epoch 14 | 424/1060 batches | 14.66ms/ batch | BCE: 0.1108 | Accuracy: 68.96% |
# Epoch 14 | 636/1060 batches | 14.63ms/ batch | BCE: 0.1131 | Accuracy: 68.00% |
# Epoch 14 | 848/1060 batches | 14.62ms/ batch | BCE: 0.1117 | Accuracy: 68.60% |
# Epoch 14 | 1060/1060 batches | 14.61ms/ batch | BCE: 0.1113 | Accuracy: 68.65% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  14 | time: 15.51s | BCE: 0.1113 | Accuracy: 68.65% |
# End of validation epoch  14 | time:  0.58s | BCE: 0.1076 | Accuracy: 71.35% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 15 | 212/1060 batches | 14.70ms/ batch | BCE: 0.1044 | Accuracy: 70.75% |
# Epoch 15 | 424/1060 batches | 14.61ms/ batch | BCE: 0.1066 | Accuracy: 69.76% |
# Epoch 15 | 636/1060 batches | 14.58ms/ batch | BCE: 0.1082 | Accuracy: 69.39% |
# Epoch 15 | 848/1060 batches | 14.57ms/ batch | BCE: 0.1090 | Accuracy: 69.09% |
# Epoch 15 | 1060/1060 batches | 14.56ms/ batch | BCE: 0.1096 | Accuracy: 68.83% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  15 | time: 15.46s | BCE: 0.1096 | Accuracy: 68.83% |
# End of validation epoch  15 | time:  0.58s | BCE: 0.1064 | Accuracy: 71.95% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 16 | 212/1060 batches | 14.85ms/ batch | BCE: 0.0990 | Accuracy: 72.41% |
# Epoch 16 | 424/1060 batches | 14.74ms/ batch | BCE: 0.1030 | Accuracy: 71.13% |
# Epoch 16 | 636/1060 batches | 14.70ms/ batch | BCE: 0.1039 | Accuracy: 70.77% |
# Epoch 16 | 848/1060 batches | 14.68ms/ batch | BCE: 0.1046 | Accuracy: 70.58% |
# Epoch 16 | 1060/1060 batches | 14.68ms/ batch | BCE: 0.1050 | Accuracy: 70.52% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  16 | time: 15.58s | BCE: 0.1050 | Accuracy: 70.52% |
# End of validation epoch  16 | time:  0.57s | BCE: 0.1043 | Accuracy: 72.26% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 17 | 212/1060 batches | 14.87ms/ batch | BCE: 0.0997 | Accuracy: 72.26% |
# Epoch 17 | 424/1060 batches | 14.77ms/ batch | BCE: 0.1022 | Accuracy: 71.53% |
# Epoch 17 | 636/1060 batches | 14.74ms/ batch | BCE: 0.1022 | Accuracy: 71.86% |
# Epoch 17 | 848/1060 batches | 14.72ms/ batch | BCE: 0.1017 | Accuracy: 71.69% |
# Epoch 17 | 1060/1060 batches | 14.71ms/ batch | BCE: 0.1023 | Accuracy: 71.46% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  17 | time: 15.62s | BCE: 0.1023 | Accuracy: 71.46% |
# End of validation epoch  17 | time:  0.59s | BCE: 0.1041 | Accuracy: 72.11% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 18 | 212/1060 batches | 14.74ms/ batch | BCE: 0.0978 | Accuracy: 72.64% |
# Epoch 18 | 424/1060 batches | 14.62ms/ batch | BCE: 0.1004 | Accuracy: 72.29% |
# Epoch 18 | 636/1060 batches | 14.57ms/ batch | BCE: 0.0998 | Accuracy: 72.31% |
# Epoch 18 | 848/1060 batches | 14.55ms/ batch | BCE: 0.0999 | Accuracy: 72.04% |
# Epoch 18 | 1060/1060 batches | 14.53ms/ batch | BCE: 0.0995 | Accuracy: 72.09% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  18 | time: 15.43s | BCE: 0.0995 | Accuracy: 72.09% |
# End of validation epoch  18 | time:  0.53s | BCE: 0.1027 | Accuracy: 72.48% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 19 | 212/1060 batches | 14.70ms/ batch | BCE: 0.0957 | Accuracy: 73.44% |
# Epoch 19 | 424/1060 batches | 14.60ms/ batch | BCE: 0.0974 | Accuracy: 73.09% |
# Epoch 19 | 636/1060 batches | 14.56ms/ batch | BCE: 0.0977 | Accuracy: 72.97% |
# Epoch 19 | 848/1060 batches | 14.55ms/ batch | BCE: 0.0983 | Accuracy: 72.78% |
# Epoch 19 | 1060/1060 batches | 14.55ms/ batch | BCE: 0.0985 | Accuracy: 72.54% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  19 | time: 15.44s | BCE: 0.0985 | Accuracy: 72.54% |
# End of validation epoch  19 | time:  0.51s | BCE: 0.1033 | Accuracy: 72.48% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 20 | 212/1060 batches | 14.69ms/ batch | BCE: 0.0971 | Accuracy: 73.44% |
# Epoch 20 | 424/1060 batches | 14.59ms/ batch | BCE: 0.0987 | Accuracy: 72.55% |
# Epoch 20 | 636/1060 batches | 14.56ms/ batch | BCE: 0.0969 | Accuracy: 73.49% |
# Epoch 20 | 848/1060 batches | 14.54ms/ batch | BCE: 0.0966 | Accuracy: 73.51% |
# Epoch 20 | 1060/1060 batches | 14.53ms/ batch | BCE: 0.0970 | Accuracy: 73.31% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  20 | time: 15.43s | BCE: 0.0970 | Accuracy: 73.31% |
# End of validation epoch  20 | time:  0.52s | BCE: 0.1022 | Accuracy: 72.63% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 21 | 212/1060 batches | 14.78ms/ batch | BCE: 0.0914 | Accuracy: 75.75% |
# Epoch 21 | 424/1060 batches | 14.69ms/ batch | BCE: 0.0907 | Accuracy: 74.88% |
# Epoch 21 | 636/1060 batches | 14.65ms/ batch | BCE: 0.0926 | Accuracy: 74.59% |
# Epoch 21 | 848/1060 batches | 14.64ms/ batch | BCE: 0.0934 | Accuracy: 74.12% |
# Epoch 21 | 1060/1060 batches | 14.63ms/ batch | BCE: 0.0937 | Accuracy: 74.14% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  21 | time: 15.53s | BCE: 0.0937 | Accuracy: 74.14% |
# End of validation epoch  21 | time:  0.59s | BCE: 0.1020 | Accuracy: 73.01% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 22 | 212/1060 batches | 14.81ms/ batch | BCE: 0.0876 | Accuracy: 76.32% |
# Epoch 22 | 424/1060 batches | 14.70ms/ batch | BCE: 0.0905 | Accuracy: 75.45% |
# Epoch 22 | 636/1060 batches | 14.65ms/ batch | BCE: 0.0912 | Accuracy: 75.19% |
# Epoch 22 | 848/1060 batches | 14.63ms/ batch | BCE: 0.0916 | Accuracy: 75.11% |
# Epoch 22 | 1060/1060 batches | 14.62ms/ batch | BCE: 0.0920 | Accuracy: 74.82% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  22 | time: 15.52s | BCE: 0.0920 | Accuracy: 74.82% |
# End of validation epoch  22 | time:  0.49s | BCE: 0.1034 | Accuracy: 71.62% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 23 | 212/1060 batches | 14.76ms/ batch | BCE: 0.0851 | Accuracy: 76.75% |
# Epoch 23 | 424/1060 batches | 14.67ms/ batch | BCE: 0.0847 | Accuracy: 76.75% |
# Epoch 23 | 636/1060 batches | 14.64ms/ batch | BCE: 0.0867 | Accuracy: 76.29% |
# Epoch 23 | 848/1060 batches | 14.63ms/ batch | BCE: 0.0875 | Accuracy: 76.19% |
# Epoch 23 | 1060/1060 batches | 14.63ms/ batch | BCE: 0.0887 | Accuracy: 75.86% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  23 | time: 15.53s | BCE: 0.0887 | Accuracy: 75.86% |
# End of validation epoch  23 | time:  0.55s | BCE: 0.1007 | Accuracy: 73.68% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 24 | 212/1060 batches | 14.83ms/ batch | BCE: 0.0842 | Accuracy: 77.83% |
# Epoch 24 | 424/1060 batches | 14.75ms/ batch | BCE: 0.0839 | Accuracy: 77.67% |
# Epoch 24 | 636/1060 batches | 14.70ms/ batch | BCE: 0.0843 | Accuracy: 77.55% |
# Epoch 24 | 848/1060 batches | 14.71ms/ batch | BCE: 0.0845 | Accuracy: 77.43% |
# Epoch 24 | 1060/1060 batches | 14.70ms/ batch | BCE: 0.0863 | Accuracy: 76.86% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  24 | time: 15.61s | BCE: 0.0863 | Accuracy: 76.86% |
# End of validation epoch  24 | time:  0.51s | BCE: 0.1006 | Accuracy: 73.46% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 25 | 212/1060 batches | 14.75ms/ batch | BCE: 0.0793 | Accuracy: 78.44% |
# Epoch 25 | 424/1060 batches | 14.68ms/ batch | BCE: 0.0847 | Accuracy: 76.96% |
# Epoch 25 | 636/1060 batches | 14.65ms/ batch | BCE: 0.0852 | Accuracy: 76.92% |
# Epoch 25 | 848/1060 batches | 14.64ms/ batch | BCE: 0.0852 | Accuracy: 76.84% |
# Epoch 25 | 1060/1060 batches | 14.62ms/ batch | BCE: 0.0856 | Accuracy: 76.73% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  25 | time: 15.52s | BCE: 0.0856 | Accuracy: 76.73% |
# End of validation epoch  25 | time:  0.58s | BCE: 0.1004 | Accuracy: 73.50% |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# Epoch 26 | 212/1060 batches | 14.67ms/ batch | BCE: 0.0803 | Accuracy: 79.15% |
# Epoch 26 | 424/1060 batches | 14.60ms/ batch | BCE: 0.0809 | Accuracy: 78.80% |
# Epoch 26 | 636/1060 batches | 14.57ms/ batch | BCE: 0.0813 | Accuracy: 78.62% |
# Epoch 26 | 848/1060 batches | 14.56ms/ batch | BCE: 0.0818 | Accuracy: 78.29% |
# Epoch 26 | 1060/1060 batches | 14.59ms/ batch | BCE: 0.0833 | Accuracy: 77.47% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch
|
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 31 | 212/1060 batches | 14.70ms/ batch | BCE: 0.0730 | Accuracy: 80.90% |
# Epoch 31 | 424/1060 batches | 14.59ms/ batch | BCE: 0.0733 | Accuracy: 80.54% |
# Epoch 31 | 636/1060 batches | 14.56ms/ batch | BCE: 0.0741 | Accuracy: 80.22% |
# Epoch 31 | 848/1060 batches | 14.54ms/ batch | BCE: 0.0739 | Accuracy: 80.46% |
# Epoch 31 | 1060/1060 batches | 14.54ms/ batch | BCE: 0.0749 | Accuracy: 80.18% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  31 | time: 15.43s | BCE: 0.0749 | Accuracy: 80.18% |
# End of validation epoch  31 | time:  0.56s | BCE: 0.0990 | Accuracy: 74.21% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 32 | 212/1060 batches | 14.74ms/ batch | BCE: 0.0662 | Accuracy: 81.93% |
# Epoch 32 | 424/1060 batches | 14.64ms/ batch | BCE: 0.0714 | Accuracy: 80.61% |
# Epoch 32 | 636/1060 batches | 14.61ms/ batch | BCE: 0.0722 | Accuracy: 80.44% |
# Epoch 32 | 848/1060 batches | 14.60ms/ batch | BCE: 0.0719 | Accuracy: 80.47% |
# Epoch 32 | 1060/1060 batches | 14.62ms/ batch | BCE: 0.0727 | Accuracy: 80.42% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  32 | time: 15.52s | BCE: 0.0727 | Accuracy: 80.42% |
# End of validation epoch  32 | time:  0.50s | BCE: 0.0980 | Accuracy: 74.66% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 33 | 212/1060 batches | 14.69ms/ batch | BCE: 0.0684 | Accuracy: 82.74% |
# Epoch 33 | 424/1060 batches | 14.60ms/ batch | BCE: 0.0683 | Accuracy: 82.31% |
# Epoch 33 | 636/1060 batches | 14.57ms/ batch | BCE: 0.0696 | Accuracy: 81.98% |
# Epoch 33 | 848/1060 batches | 14.56ms/ batch | BCE: 0.0711 | Accuracy: 81.08% |
# Epoch 33 | 1060/1060 batches | 14.55ms/ batch | BCE: 0.0709 | Accuracy: 81.12% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  33 | time: 15.45s | BCE: 0.0709 | Accuracy: 81.12% |
# End of validation epoch  33 | time:  0.58s | BCE: 0.0986 | Accuracy: 73.61% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 34 | 212/1060 batches | 14.83ms/ batch | BCE: 0.0696 | Accuracy: 82.17% |
# Epoch 34 | 424/1060 batches | 14.72ms/ batch | BCE: 0.0681 | Accuracy: 82.38% |
# Epoch 34 | 636/1060 batches | 14.67ms/ batch | BCE: 0.0683 | Accuracy: 82.58% |
# Epoch 34 | 848/1060 batches | 14.65ms/ batch | BCE: 0.0685 | Accuracy: 82.52% |
# Epoch 34 | 1060/1060 batches | 14.63ms/ batch | BCE: 0.0681 | Accuracy: 82.61% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  34 | time: 15.54s | BCE: 0.0681 | Accuracy: 82.61% |
# End of validation epoch  34 | time:  0.48s | BCE: 0.0986 | Accuracy: 73.83% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 35 | 212/1060 batches | 14.70ms/ batch | BCE: 0.0641 | Accuracy: 83.25% |
# Epoch 35 | 424/1060 batches | 14.64ms/ batch | BCE: 0.0654 | Accuracy: 82.76% |
# Epoch 35 | 636/1060 batches | 14.63ms/ batch | BCE: 0.0657 | Accuracy: 83.00% |
# Epoch 35 | 848/1060 batches | 14.60ms/ batch | BCE: 0.0655 | Accuracy: 82.91% |
# Epoch 35 | 1060/1060 batches | 14.58ms/ batch | BCE: 0.0662 | Accuracy: 82.79% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch
|
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 40 | 212/1060 batches | 14.67ms/ batch | BCE: 0.0586 | Accuracy: 85.24% |
# Epoch 40 | 424/1060 batches | 14.60ms/ batch | BCE: 0.0578 | Accuracy: 85.19% |
# Epoch 40 | 636/1060 batches | 14.62ms/ batch | BCE: 0.0582 | Accuracy: 84.92% |
# Epoch 40 | 848/1060 batches | 14.63ms/ batch | BCE: 0.0579 | Accuracy: 85.11% |
# Epoch 40 | 1060/1060 batches | 14.63ms/ batch | BCE: 0.0577 | Accuracy: 85.06% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  40 | time: 15.53s | BCE: 0.0577 | Accuracy: 85.06% |
# End of validation epoch  40 | time:  0.50s | BCE: 0.0983 | Accuracy: 73.83% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 41 | 212/1060 batches | 14.76ms/ batch | BCE: 0.0522 | Accuracy: 87.45% |
# Epoch 41 | 424/1060 batches | 14.68ms/ batch | BCE: 0.0555 | Accuracy: 86.53% |
# Epoch 41 | 636/1060 batches | 14.64ms/ batch | BCE: 0.0559 | Accuracy: 86.26% |
# Epoch 41 | 848/1060 batches | 14.61ms/ batch | BCE: 0.0573 | Accuracy: 85.86% |
# Epoch 41 | 1060/1060 batches | 14.61ms/ batch | BCE: 0.0563 | Accuracy: 86.08% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  41 | time: 15.51s | BCE: 0.0563 | Accuracy: 86.08% |
# End of validation epoch  41 | time:  0.54s | BCE: 0.0987 | Accuracy: 74.51% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 42 | 212/1060 batches | 14.71ms/ batch | BCE: 0.0533 | Accuracy: 86.84% |
# Epoch 42 | 424/1060 batches | 14.63ms/ batch | BCE: 0.0525 | Accuracy: 86.75% |
# Epoch 42 | 636/1060 batches | 14.60ms/ batch | BCE: 0.0536 | Accuracy: 86.46% |
# Epoch 42 | 848/1060 batches | 14.59ms/ batch | BCE: 0.0545 | Accuracy: 86.26% |
# Epoch 42 | 1060/1060 batches | 14.59ms/ batch | BCE: 0.0549 | Accuracy: 86.05% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  42 | time: 15.49s | BCE: 0.0549 | Accuracy: 86.05% |
# End of validation epoch  42 | time:  0.58s | BCE: 0.0991 | Accuracy: 73.68% |
# ---------------------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------------------------------
# Epoch 43 | 212/1060 batches | 14.77ms/ batch | BCE: 0.0525 | Accuracy: 86.08% |
# Epoch 43 | 424/1060 batches | 14.69ms/ batch | BCE: 0.0523 | Accuracy: 86.89% |
# Epoch 43 | 636/1060 batches | 14.66ms/ batch | BCE: 0.0534 | Accuracy: 86.54% |
# Epoch 43 | 848/1060 batches | 14.63ms/ batch | BCE: 0.0529 | Accuracy: 86.75% |
# Epoch 43 | 1060/1060 batches | 14.62ms/ batch | BCE: 0.0525 | Accuracy: 86.87% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  43 | time: 15.52s | BCE: 0.0525 | Accuracy: 86.87% |
# End of validation epoch  43 | time:  0.49s | BCE: 0.0986 | Accuracy: 73.91% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 44 | 212/1060 batches | 14.71ms/ batch | BCE: 0.0492 | Accuracy: 87.45% |
# Epoch 44 | 424/1060 batches | 14.61ms/ batch | BCE: 0.0500 | Accuracy: 87.48% |
# Epoch 44 | 636/1060 batches | 14.57ms/ batch | BCE: 0.0490 | Accuracy: 87.61% |
# Epoch 44 | 848/1060 batches | 14.55ms/ batch | BCE: 0.0501 | Accuracy: 87.32% |
# Epoch 44 | 1060/1060 batches | 14.55ms/ batch | BCE: 0.0505 | Accuracy: 87.24% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  44 | time: 15.44s | BCE: 0.0505 | Accuracy: 87.24% |
# End of validation epoch  44 | time:  0.49s | BCE: 0.0978 | Accuracy: 74.21% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 45 | 212/1060 batches | 14.79ms/ batch | BCE: 0.0459 | Accuracy: 88.82% |
# Epoch 45 | 424/1060 batches | 14.69ms/ batch | BCE: 0.0474 | Accuracy: 88.28% |
# Epoch 45 | 636/1060 batches | 14.67ms/ batch | BCE: 0.0474 | Accuracy: 87.99% |
# Epoch 45 | 848/1060 batches | 14.62ms/ batch | BCE: 0.0487 | Accuracy: 87.57% |
# Epoch 45 | 1060/1060 batches | 14.59ms/ batch | BCE: 0.0490 | Accuracy: 87.38% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  45 | time: 15.49s | BCE: 0.0490 | Accuracy: 87.38% |
# End of validation epoch  45 | time:  0.59s | BCE: 0.0981 | Accuracy: 74.81% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch 46 | 212/1060 batches | 14.78ms/ batch | BCE: 0.0455 | Accuracy: 88.82% |
# Epoch 46 | 424/1060 batches | 14.67ms/ batch | BCE: 0.0485 | Accuracy: 87.95% |
# Epoch 46 | 636/1060 batches | 14.63ms/ batch | BCE: 0.0489 | Accuracy: 87.78% |
# Epoch 46 | 848/1060 batches | 14.61ms/ batch | BCE: 0.0497 | Accuracy: 87.50% |
# Epoch 46 | 1060/1060 batches | 14.60ms/ batch | BCE: 0.0493 | Accuracy: 87.58% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  46 | time: 15.50s | BCE: 0.0493 | Accuracy: 87.58% |
# End of validation epoch  46 | time:  0.59s | BCE: 0.0996 | Accuracy: 73.01% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 47 | 212/1060 batches | 14.73ms/ batch | BCE: 0.0471 | Accuracy: 87.69% |
# Epoch 47 | 424/1060 batches | 14.64ms/ batch | BCE: 0.0464 | Accuracy: 88.02% |
# Epoch 47 | 636/1060 batches | 14.61ms/ batch | BCE: 0.0459 | Accuracy: 88.33% |
# Epoch 47 | 848/1060 batches | 14.60ms/ batch | BCE: 0.0458 | Accuracy: 88.30% |
# Epoch 47 | 1060/1060 batches | 14.58ms/ batch | BCE: 0.0458 | Accuracy: 88.34% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  47 | time: 15.48s | BCE: 0.0458 | Accuracy: 88.34% |
# End of validation epoch  47 | time:  0.58s | BCE: 0.0993 | Accuracy: 74.14% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 48 | 212/1060 batches | 14.63ms/ batch | BCE: 0.0435 | Accuracy: 88.49% |
# Epoch 48 | 424/1060 batches | 14.57ms/ batch | BCE: 0.0449 | Accuracy: 88.80% |
# Epoch 48 | 636/1060 batches | 14.55ms/ batch | BCE: 0.0448 | Accuracy: 88.88% |
# Epoch 48 | 848/1060 batches | 14.53ms/ batch | BCE: 0.0452 | Accuracy: 88.71% |
# Epoch 48 | 1060/1060 batches | 14.52ms/ batch | BCE: 0.0454 | Accuracy: 88.60% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  48 | time: 15.42s | BCE: 0.0454 | Accuracy: 88.60% |
# End of validation epoch  48 | time:  0.50s | BCE: 0.0993 | Accuracy: 74.44% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 49 | 212/1060 batches | 14.66ms/ batch | BCE: 0.0410 | Accuracy: 89.81% |
# Epoch 49 | 424/1060 batches | 14.58ms/ batch | BCE: 0.0417 | Accuracy: 89.55% |
# Epoch 49 | 636/1060 batches | 14.57ms/ batch | BCE: 0.0431 | Accuracy: 89.12% |
# Epoch 49 | 848/1060 batches | 14.58ms/ batch | BCE: 0.0425 | Accuracy: 89.37% |
# Epoch 49 | 1060/1060 batches | 14.59ms/ batch | BCE: 0.0430 | Accuracy: 89.33% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  49 | time: 15.49s | BCE: 0.0430 | Accuracy: 89.33% |
# End of validation epoch  49 | time:  0.52s | BCE: 0.0995 | Accuracy: 74.36% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 50 | 212/1060 batches | 14.82ms/ batch | BCE: 0.0410 | Accuracy: 90.00% |
# Epoch 50 | 424/1060 batches | 14.72ms/ batch | BCE: 0.0413 | Accuracy: 89.95% |
# Epoch 50 | 636/1060 batches | 14.67ms/ batch | BCE: 0.0416 | Accuracy: 90.02% |
# Epoch 50 | 848/1060 batches | 14.66ms/ batch | BCE: 0.0415 | Accuracy: 89.83% |
# Epoch 50 | 1060/1060 batches | 14.65ms/ batch | BCE: 0.0422 | Accuracy: 89.79% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  50 | time: 15.56s | BCE: 0.0422 | Accuracy: 89.79% |
# End of validation epoch  50 | time:  0.51s | BCE: 0.0995 | Accuracy: 73.83% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Model Analysis

# %%
plt.figure(figsize=(10, 5))
plt.plot(log['train_loss'], '--', color=(1,0,0,0.8), label='BCE_LOSS (Train)')
plt.plot(log['valid_loss'], '--', color=(0,0,1,0.8), label='BCE_LOSS (Validation)')
plt.tight_layout()
plt.legend(loc="best")
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(log['train_accu'], '--', color=(1,0,0,0.8), label='Accuracy (Train)')
plt.plot(log['valid_accu'], '--', color=(0,0,1,0.8), label='Accuracy (Validation)')
plt.tight_layout()
plt.legend(loc="best")
plt.show()

# %% [markdown]
# ## Test Model on test set

# %%
from Train import validate_test
import torch

# %%
txtModel = Model()
txtModel.cuda().load_state_dict(torch.load(Settings.model_save_folder + 'model.h5'))
validate_test(model=txtModel, epoch=0, use_loader=test_loader)
# Out:
# End of validation epoch   0 | time:  0.59s | BCE: 0.0971 | Accuracy: 75.19% |
# ---------------------------------------------------------------------------------------------------
# (0.09707279448201389, 0.7518796992481203)

# %% [markdown]
# ## Confusion Matrix

# %%
from Evaluate import Evaluator
model = Model()
evaluator = Evaluator(model, "model.h5")

# %%
evaluator.record_matrix(test_loader, "textCNNconfusion.json")
# Out:
# End of Matrix Record, Save file in ../LogSave/textCNNconfusion.json
# ---------------------------------------------------------------------------------------------------

# %%
import numpy as np
import pandas as pd
import seaborn as sn

# %%
matrix = np.zeros((Settings.class_num, Settings.class_num))
with open(Settings.log_save_folder + 'textCNNconfusion.json', 'r') as f:
    tuple_list = json.load(f)

# %%
for point in tuple_list:
    i, j = point  # i is predict, j is real, record 100 point for each label
    matrix[i][j] += 1

# %%
matrix /= sum(matrix)
matrix = pd.DataFrame(matrix, index = [evaluator.index_to_label.get(str(i+1)) for i in range(Settings.class_num)],
                  columns = [evaluator.index_to_label.get(str(i+1)) for i in range(Settings.class_num)],)

# %% [markdown]
# ## Conclusion
# Current model has 74% accuracy on "chunk test"

# %% [markdown]
# # Test model on original set

# %%
import csv

csv_file = open(Settings.data_path, "r")
csv_reader = csv.reader(csv_file)

count = 0
right_count = 0
for line in csv_reader:
    label, doc = line
    pred_label, score = evaluator.label_predict(doc)
    count += 1
    if pred_label == label:
        right_count += 1

csv_file.close()
print(count, right_count)
# Out:
# 62204 50280

# %%
right_count/ count
# Out:
# 0.8083081473860202

# %% [markdown]
# # Current Model Result
#
# - 80% on full length document
# - 75% on chunks

# %% [markdown]
# # Train Model Use Full Set

# %%
# Dataloaders
e_train_loader = torch_dataset_loader(Settings.e_train_path, Settings.batch_size, True, Settings.kwargs)
e_validation_loader = torch_dataset_loader(Settings.e_valid_path, Settings.batch_size, False, Settings.kwargs)
e_test_loader = torch_dataset_loader(Settings.e_test_path, Settings.batch_size, False, Settings.kwargs)

# %%
fulltxtModel = Model()
e_log = main_train(fulltxtModel, e_train_loader, e_validation_loader, "e_train.json", "e_model.h5")
# Out:
# Epoch  1 | 2144/10720 batches | 14.55ms/ batch | BCE: 0.1866 | Accuracy: 45.72% |
# Epoch  1 | 4288/10720 batches | 14.53ms/ batch | BCE: 0.1666 | Accuracy: 52.32% |
# Epoch  1 | 6432/10720 batches | 14.56ms/ batch | BCE: 0.1547 | Accuracy: 56.12% |
# Epoch  1 | 8576/10720 batches | 14.58ms/ batch | BCE: 0.1468 | Accuracy: 58.58% |
# Epoch  1 | 10720/10720 batches | 14.58ms/ batch | BCE: 0.1411 | Accuracy: 60.27% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   1 | time: 156.34s | BCE: 0.1411 | Accuracy: 60.27% |
# End of validation epoch   1 | time:  4.82s | BCE: 0.0956 | Accuracy: 74.00% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  2 | 2144/10720 batches | 14.70ms/ batch | BCE: 0.1123 | Accuracy: 69.27% |
# Epoch  2 | 4288/10720 batches | 14.65ms/ batch | BCE: 0.1111 | Accuracy: 69.49% |
# Epoch  2 | 6432/10720 batches | 14.63ms/ batch | BCE: 0.1103 | Accuracy: 69.68% |
# Epoch  2 | 8576/10720 batches | 14.62ms/ batch | BCE: 0.1094 | Accuracy: 69.95% |
# Epoch  2 | 10720/10720 batches | 14.62ms/ batch | BCE: 0.1085 | Accuracy: 70.21% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   2 | time: 156.75s | BCE: 0.1085 | Accuracy: 70.21% |
# End of validation epoch   2 | time:  4.91s | BCE: 0.0876 | Accuracy: 76.29% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch  3 | 2144/10720 batches | 14.63ms/ batch | BCE: 0.1024 | Accuracy: 72.02% |
# Epoch  3 | 4288/10720 batches | 14.61ms/ batch | BCE: 0.1023 | Accuracy: 72.13% |
# Epoch  3 | 6432/10720 batches | 14.62ms/ batch | BCE: 0.1010 | Accuracy: 72.48% |
# Epoch  3 | 8576/10720 batches | 14.61ms/ batch | BCE: 0.1007 | Accuracy: 72.69% |
# Epoch  3 | 10720/10720 batches | 14.61ms/ batch | BCE: 0.1003 | Accuracy: 72.83% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch   3 | time: 156.59s | BCE: 0.1003 | Accuracy: 72.83% |
# End of validation epoch   3 | time:  4.73s | BCE: 0.0846 | Accuracy: 76.94% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ***Best Validation Model Found and Saved***
# ---------------------------------------------------------------------------------------------------
# Epoch
|
# ---------------------------------------------------------------------------------------------------
# End of training epoch  48 | time: 157.09s | BCE: 0.0325 | Accuracy: 92.10% |
# End of validation epoch  48 | time:  4.62s | BCE: 0.1070 | Accuracy: 79.76% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------
# Epoch 49 | 2144/10720 batches | 14.63ms/ batch | BCE: 0.0290 | Accuracy: 92.92% |
# Epoch 49 | 4288/10720 batches | 14.63ms/ batch | BCE: 0.0305 | Accuracy: 92.50% |
# Epoch 49 | 6432/10720 batches | 14.61ms/ batch | BCE: 0.0314 | Accuracy: 92.28% |
# Epoch 49 | 8576/10720 batches | 14.61ms/ batch | BCE: 0.0315 | Accuracy: 92.29% |
# Epoch 50 | 6432/10720 batches | 14.66ms/ batch | BCE: 0.0309 | Accuracy: 92.36% |
# Epoch 50 | 8576/10720 batches | 14.64ms/ batch | BCE: 0.0314 | Accuracy: 92.30% |
# Epoch 50 | 10720/10720 batches | 14.64ms/ batch | BCE: 0.0319 | Accuracy: 92.17% |
# ---------------------------------------------------------------------------------------------------
# End of training epoch  50 | time: 157.00s | BCE: 0.0319 | Accuracy: 92.17% |
# End of validation epoch  50 | time:  4.58s | BCE: 0.1105 | Accuracy: 79.93% |
# ---------------------------------------------------------------------------------------------------
# ***Found Best Training Model***
# ---------------------------------------------------------------------------------------------------

# %%
plt.figure(figsize=(10, 5))
plt.plot(e_log['train_loss'], '--', color=(1,0,0,0.8), label='BCE_LOSS (Train)')
plt.plot(e_log['valid_loss'], '--', color=(0,0,1,0.8), label='BCE_LOSS (Validation)')
plt.tight_layout()
plt.legend(loc="best")
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.plot(e_log['train_accu'], '--', color=(1,0,0,0.8), label='Accuracy (Train)')
plt.plot(e_log['valid_accu'], '--', color=(0,0,1,0.8), label='Accuracy (Validation)')
plt.tight_layout()
plt.legend(loc="best")
plt.show()

# %% [markdown]
# As seen in picture, there is overfitting

# %%
fulltxtModel = Model()
fulltxtModel.cuda().load_state_dict(torch.load(Settings.model_save_folder + 'e_model.h5'))
validate_test(model=fulltxtModel, epoch=0, use_loader=e_test_loader)
# Out:
# End of validation epoch   0 | time:  4.73s | BCE: 0.0806 | Accuracy: 79.60% |
# ---------------------------------------------------------------------------------------------------
# (0.0805757327305862, 0.7959701492537267)

# %% [markdown]
# The model has 80% accuracy over test set

# %%
full_evaluator = Evaluator(fulltxtModel, "e_model.h5")

# %%
full_evaluator.record_matrix(e_test_loader, "textCNNconfusion-full.json")
# Out:
# End of Matrix Record, Save file in ../LogSave/textCNNconfusion-full.json
# ---------------------------------------------------------------------------------------------------

# %%
matrix = np.zeros((Settings.class_num, Settings.class_num))
with open(Settings.log_save_folder + 'textCNNconfusion-full.json', 'r') as f:
    tuple_list = json.load(f)
for point in tuple_list:
    i, j = point  # i is predict, j is real, record 100 point for each label
    matrix[i][j] += 1
matrix /= sum(matrix)
matrix = pd.DataFrame(matrix, index = [evaluator.index_to_label.get(str(i+1)) for i in range(Settings.class_num)],
                  columns = [evaluator.index_to_label.get(str(i+1)) for i in range(Settings.class_num)],)
plt.figure(figsize=(12, 8))
plt.title('Text CNN Model on Full Data')
sn.heatmap(matrix, annot=True,)
plt.tight_layout()
plt.show()
